# %% [markdown]
# <a href="https://colab.research.google.com/github/alanadedla/alanadedla.github.io/blob/main/workbooks/Lecture02_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 2 Workbook

# %% [markdown]
# ### 1.

# %% [markdown]
# Print greeting to your fellow student.

# %%
print("Hello Fellow Student!")
# Out:
# Hello Fellow Student!

# %% [markdown]
# ### 2.

# %% [markdown]
# Print the following statement:
#
#     "The only way to do great work is to love what you do." - Steve Jobs

# %%
print('"The only way to do great work is to love what you do." - Steve Jobs')
# Out:
# "The only way to do great work is to love what you do." - Steve Jobs

# %% [markdown]
# ### 3.

# %% [markdown]
# Print the following statement:
#
#     "You're never too old to set a new goal or dream a new dream." - C.S. Lewis

# %%
print('"You\'re never too old to set a new goal or dream a new dream" - C.S Lewis')
# Out:
# "You're never too old to set a new goal or dream a new dream" - C.S Lewis

# %% [markdown]
# ### 4.

# %% [markdown]
# What is 5 to the power of 5?

# %%
print(5**5)
# Out:
# 3125

# %% [markdown]
# ### 5.

# %% [markdown]
# What is the remainder from dividing 73 by 6?

# %%
print(73%6)
# Out:
# 1

# %% [markdown]
# ### 6.

# %% [markdown]
# How many times does the whole number 3 go into 123? What is the remainder of dividing 123 by 3?

# %%
print(123/3)
print(123%3)
# Out:
# 41.0
# 0

# %% [markdown]
# ### 7.

# %% [markdown]
# Given the following variables:
#
# ```
# thing = "light"
# speed = 299792458  # m/s
# ```
#
# Use f-strings to print:
#
# ```
# The speed of light is 2.997925e+08 m/s.
# ```

# %%
thing = "light"
speed = 299792458  # m/s
print(f"The speed of {thing} is {speed} m/s")
# Out:
# The speed of light is 299792458 m/s
